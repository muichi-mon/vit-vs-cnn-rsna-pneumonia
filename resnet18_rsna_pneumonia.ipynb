# %% [markdown]
# # **Set-Up**

# %%
# %pip install torchio --q
# %pip install monai --q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 9.8 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 45.1 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pytorch_lightning as pl
import torchio as tio 
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

import pydicom

import math
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from tqdm.notebook import trange, tqdm
from pathlib import Path
from tqdm import tqdm

# %matplotlib inline

# %% [markdown]
# # **Pre-Processing**

# %%
labels_df = pd.read_csv(
    "/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_labels.csv"
)

labels_df = labels_df.groupby("patientId")["Target"].max().reset_index()

print(labels_df["Target"].value_counts())
print(labels_df.info(verbose=True, show_counts=True))
# Out:
# Target
# 0    20672
# 1     6012
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26684 entries, 0 to 26683
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patientId  26684 non-null  object
#  1   Target     26684 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 417.1+ KB
# None

# %%
labels_df.head()
# Out:
#                               patientId  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6       0
# 1  000924cf-0f8d-42bd-9158-1af53881a557       0
# 2  000db696-cf54-4385-b10b-6b16fbb3f985       1
# 3  000fe35a-2649-43d4-b027-e67796d412e0       1
# 4  001031d9-f904-4a23-b3e5-2c088acd19c6       1

# %% [markdown]
# ## Subjects

# %%
ROOT_PATH = Path("/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_images/")
patient_dirs = list(ROOT_PATH.glob("*"))

patient_dirs[0] # debug
# Out:
# PosixPath('/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_images/c3b05294-29be-46e4-8a51-96fd211e4ca5.dcm')

# %%
ds = pydicom.dcmread(patient_dirs[0])
img = ds.pixel_array

img.shape
# Out:
# (1024, 1024)

# %%
def get_patient_label(patient_path: Path, labels_df: pd.DataFrame) -> int:
    patientID = patient_path.stem
    label = labels_df.loc[labels_df["patientId"] == patientID, "Target"]
    label = label.iloc[0] if not label.empty else None
    return int(label)

# %%
subjects = []
heights = []
widths = []
labels = []

for subject_path in tqdm(patient_dirs):
    
    img_path = subject_path
    label = get_patient_label(subject_path, labels_df)

    ct = tio.ScalarImage(img_path)
    h, w, _ = ct.spatial_shape   

    subject = tio.Subject(
        CT = ct,
        Label = torch.tensor(label, dtype=torch.long),
        PatientID = subject_path.stem
    )

    subjects.append(subject)
    heights.append(h)
    widths.append(w)
    labels.append(label)
# Out:
# 100%|██████████| 26684/26684 [08:41<00:00, 51.22it/s]

# %%
print(type(subjects[15]["CT"]), subjects[15]["CT"])
print(type(subjects[15]["Label"]), subjects[15]["Label"])
subjects[15]["CT"].spatial_shape
# Out:
# <class 'torchio.data.image.ScalarImage'> ScalarImage(shape: (1, 1024, 1024, 1); spacing: (0.17, 0.17, 1.00); orientation: LPS+; path: "/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_images/7625412b-fbb0-46d7-9f7d-00b436cc467a.dcm")
# <class 'torch.Tensor'> tensor(1)
# (1024, 1024, 1)

# %%
# Plot depth (dimensions)
plt.figure(figsize=(18,5))

# Plot height
plt.subplot(1,2,1)
plt.hist(heights, bins=20, color='lightgreen', edgecolor='black')
plt.title("CT Height Distribution")
plt.xlabel("Height (pixels/voxels)")
plt.ylabel("Number of Subjects")

# Plot width
plt.subplot(1,2,2)
plt.hist(widths, bins=20, color='salmon', edgecolor='black')
plt.title("CT Width Distribution")
plt.xlabel("Width (pixels/voxels)")
plt.ylabel("Number of Subjects")

plt.tight_layout()
plt.show()

# %%
img_size_og = subjects[15]["CT"].spatial_shape[0]

# %% [markdown]
# ## **Transforms**

# %%
process = tio.Compose([
    tio.ToCanonical(),                        # step 1: fix orientation - RAS              
    tio.RescaleIntensity((0, 1)),                      # step 2: normalize intensity
    tio.Resize((356, 356, 1)),
    tio.CropOrPad((256, 256, 1)),          
])

augmentation = tio.RandomAffine(scales=(0.9, 1.1), degrees=(-10, 10))

train_transform = tio.Compose([process, augmentation])
val_transform = tio.Compose([process])

# %% [markdown]
# ## **DataSet & DataLoader**

# %%
from sklearn.model_selection import train_test_split

# (90/10)
train_val_subjects, test_subjects = train_test_split(
    subjects,
    test_size=0.15,
    stratify=labels,
    random_state=42
)

# (80/20)
train_subjects, val_subjects = train_test_split(
    train_val_subjects,
    test_size=0.2,
    stratify=[s.Label.item() for s in train_val_subjects],
    random_state=42
)

# Verify class distributions
train_labels = [s.Label.item() for s in train_subjects]
val_labels   = [s.Label.item() for s in val_subjects]
test_labels  = [s.Label.item() for s in test_subjects]

print("Train counts:", np.bincount(train_labels))
print("Val counts:", np.bincount(val_labels))
print("Test counts:", np.bincount(test_labels))
# Out:
# Train counts: [14056  4088]
# Val counts: [3515 1022]
# Test counts: [3101  902]

# %%
train_dataset = tio.SubjectsDataset(train_subjects, transform = train_transform) 
val_dataset = tio.SubjectsDataset(val_subjects, transform = val_transform)  
test_dataset = tio.SubjectsDataset(test_subjects, transform = val_transform)

# %%
from typing import Tuple, List

def collate_subjects(batch: List) -> Tuple[torch.Tensor, torch.Tensor]:
    images = torch.stack([s.CT.data.squeeze(-1) for s in batch])
    labels = torch.tensor([s.Label.item() for s in batch])
    return images, labels

# %%
train_loader = DataLoader(train_dataset, batch_size=8, num_workers=4, collate_fn=collate_subjects, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, num_workers=4, collate_fn=collate_subjects)
test_loader = DataLoader(test_dataset, batch_size=8, num_workers=4, collate_fn=collate_subjects)

# %%
x, y = next(iter(train_loader))
print(f"Images shape fresh off the loader: {x.shape}")
print(f"Labels shape fresh off the loader: {y.shape}")
print("Labels corresponding to 8 images in the batch: " + str(y))
# Out:
# Images shape fresh off the loader: torch.Size([8, 1, 256, 256])
# Labels shape fresh off the loader: torch.Size([8])
# Labels corresponding to 8 images in the batch: tensor([0, 0, 1, 0, 0, 1, 0, 0])

# %% [markdown]
# # **Model**

# %%
img_size = x.shape[2]
img_size
# Out:
# 256

# %%
channels_in = x.shape[1]
print(f"Input Channels: {channels_in}")

num_classes = 1
print(f"Output Channels: {num_classes}")

learning_rate = 3e-4
# Out:
# Input Channels: 1
# Output Channels: 1

# %%
import torchvision.models as models
model = models.resnet18(pretrained=True);
model
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 204MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 1)

model
# Out:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model.to(device);

# %% [markdown]
# # **Train**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
criterion = nn.BCEWithLogitsLoss()

# %%
# print(model)
x = torch.randn(8, 1, 256, 256).to(device)
y = model(x)
print(y.shape)
print(f"How likely (logits) the model predicts each image in the batch to be pneumonic: \n{y}")
# y.argmax(dim=0)
# Out:
# torch.Size([8, 1])
# How likely (logits) the model predicts each image in the batch to be pneumonic:
# tensor([[1.2537],
#         [0.2764],
#         [0.6453],
#         [0.8978],
#         [0.4703],
#         [0.9963],
#         [1.2770],
#         [0.6188]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
num_model_params = 0
for param in model.parameters():
    num_model_params += param.flatten().shape[0]

print("-This Model Has %d (Approximately %d Million) Parameters!" % (num_model_params, num_model_params//1e6))
# Out:
# -This Model Has 11170753 (Approximately 11 Million) Parameters!

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc

# %%
epochs = 30

for epoch in range(epochs):
    model.train()
    total_loss = 0
    all_preds = []
    all_labels = []
    print(f"\nEpoch {epoch+1}")

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        labels = labels.float().unsqueeze(1)  # (B,1)

        optimizer.zero_grad()
        logits = model(images)                 # (B,1)
        
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # --- compute predictions ---
        probs = torch.sigmoid(logits)          # (B,1)
        preds = (probs > 0.5).long()           # binary 0/1
        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu().long())

        if batch_idx % 500 == 0:
            batch_acc = accuracy_score(
                labels.cpu().numpy(), preds.cpu().numpy()
            ) * 100
            print(f"\nBatch {batch_idx+1:3d}: Loss = {loss.item():.4f} | Accuracy = {batch_acc:.2f}%")

    # --- epoch metrics ---
    all_preds_tensor = torch.cat(all_preds, dim=0)
    all_labels_tensor = torch.cat(all_labels, dim=0)

    epoch_acc = accuracy_score(all_labels_tensor.numpy(), all_preds_tensor.numpy()) * 100
    print(f"===> Epoch {epoch+1} Summary: Total Loss = {total_loss:.4f} | Accuracy = {epoch_acc:.2f}%")

torch.save(
    {
        "epoch": epoch + 1,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "loss": total_loss,
    },
    "last_epoch_checkpoint.pth"
)
# Out:
# Epoch 1
#
# Batch   1: Loss = 0.9072 | Accuracy = 37.50%
#
# Batch 501: Loss = 0.5248 | Accuracy = 75.00%
#
# Batch 1001: Loss = 0.2786 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.3751 | Accuracy = 75.00%
#
# Batch 2001: Loss = 0.7528 | Accuracy = 62.50%
# ===> Epoch 1 Summary: Total Loss = 989.0765 | Accuracy = 79.51%
#
# Epoch 2
#
# Batch   1: Loss = 0.2696 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.4660 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2665 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.5378 | Accuracy = 62.50%
#
# Batch 2001: Loss = 0.4214 | Accuracy = 75.00%
# ===> Epoch 2 Summary: Total Loss = 927.4731 | Accuracy = 81.40%
#
# Epoch 3
#
# Batch   1: Loss = 0.3221 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.3374 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.6050 | Accuracy = 62.50%
#
# Batch 1501: Loss = 0.1469 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.3359 | Accuracy = 87.50%
# ===> Epoch 3 Summary: Total Loss = 895.1907 | Accuracy = 82.23%
#
# Epoch 4
#
# Batch   1: Loss = 0.3370 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.2751 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.6460 | Accuracy = 62.50%
#
# Batch 1501: Loss = 0.4173 | Accuracy = 75.00%
#
# Batch 2001: Loss = 0.6326 | Accuracy = 75.00%
# ===> Epoch 4 Summary: Total Loss = 879.3870 | Accuracy = 82.16%
#
# Epoch 5
#
# Batch   1: Loss = 0.2772 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.2605 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2289 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.6381 | Accuracy = 75.00%
#
# Batch 2001: Loss = 0.4321 | Accuracy = 75.00%
# ===> Epoch 5 Summary: Total Loss = 854.8839 | Accuracy = 82.77%
#
# Epoch 6
#
# Batch   1: Loss = 0.3014 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.3622 | Accuracy = 75.00%
#
# Batch 1001: Loss = 0.5763 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.2779 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.4265 | Accuracy = 62.50%
# ===> Epoch 6 Summary: Total Loss = 843.0061 | Accuracy = 83.29%
#
# Epoch 7
#
# Batch   1: Loss = 0.5083 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.2330 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.5048 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.1791 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.1259 | Accuracy = 100.00%
# ===> Epoch 7 Summary: Total Loss = 835.7151 | Accuracy = 83.56%
#
# Epoch 8
#
# Batch   1: Loss = 0.1886 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.2159 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2594 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.1502 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.5498 | Accuracy = 75.00%
# ===> Epoch 8 Summary: Total Loss = 822.7071 | Accuracy = 83.57%
#
# Epoch 9
#
# Batch   1: Loss = 0.3215 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.6953 | Accuracy = 75.00%
#
# Batch 1001: Loss = 0.4976 | Accuracy = 62.50%
#
# Batch 1501: Loss = 0.2587 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.2533 | Accuracy = 100.00%
# ===> Epoch 9 Summary: Total Loss = 812.4933 | Accuracy = 83.83%
#
# Epoch 10
#
# Batch   1: Loss = 0.8364 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.2056 | Accuracy = 100.00%
#
# Batch 1001: Loss = 1.1390 | Accuracy = 62.50%
#
# Batch 1501: Loss = 0.4302 | Accuracy = 62.50%
#
# Batch 2001: Loss = 0.4365 | Accuracy = 87.50%
# ===> Epoch 10 Summary: Total Loss = 795.2221 | Accuracy = 84.38%
#
# Epoch 11
#
# Batch   1: Loss = 0.1576 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.3562 | Accuracy = 75.00%
#
# Batch 1001: Loss = 0.2061 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.1557 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.2116 | Accuracy = 100.00%
# ===> Epoch 11 Summary: Total Loss = 786.3980 | Accuracy = 84.46%
#
# Epoch 12
#
# Batch   1: Loss = 0.4837 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.1833 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2082 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.2133 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.1208 | Accuracy = 100.00%
# ===> Epoch 12 Summary: Total Loss = 775.6263 | Accuracy = 84.90%
#
# Epoch 13
#
# Batch   1: Loss = 0.2457 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.9967 | Accuracy = 62.50%
#
# Batch 1001: Loss = 0.2404 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.4133 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.4050 | Accuracy = 87.50%
# ===> Epoch 13 Summary: Total Loss = 756.8070 | Accuracy = 85.20%
#
# Epoch 14
#
# Batch   1: Loss = 0.2603 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.1851 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.4111 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.1725 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.5787 | Accuracy = 75.00%
# ===> Epoch 14 Summary: Total Loss = 752.1307 | Accuracy = 85.49%
#
# Epoch 15
#
# Batch   1: Loss = 0.6174 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.2498 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.3689 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.2695 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.8099 | Accuracy = 75.00%
# ===> Epoch 15 Summary: Total Loss = 738.5417 | Accuracy = 85.50%
#
# Epoch 16
#
# Batch   1: Loss = 0.3275 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.2749 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.1077 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.1777 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.0826 | Accuracy = 100.00%
# ===> Epoch 16 Summary: Total Loss = 715.9937 | Accuracy = 86.06%
#
# Epoch 17
#
# Batch   1: Loss = 0.7525 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.1223 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.2113 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.3235 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.3620 | Accuracy = 87.50%
# ===> Epoch 17 Summary: Total Loss = 706.2214 | Accuracy = 86.60%
#
# Epoch 18
#
# Batch   1: Loss = 0.2084 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.2708 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2404 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.2101 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.2951 | Accuracy = 87.50%
# ===> Epoch 18 Summary: Total Loss = 676.9185 | Accuracy = 87.06%
#
# Epoch 19
#
# Batch   1: Loss = 0.1301 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.2326 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.1965 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.4999 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.2812 | Accuracy = 75.00%
# ===> Epoch 19 Summary: Total Loss = 659.8195 | Accuracy = 87.56%
#
# Epoch 20
#
# Batch   1: Loss = 0.3603 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.2193 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.3300 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.2768 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.1866 | Accuracy = 100.00%
# ===> Epoch 20 Summary: Total Loss = 638.3047 | Accuracy = 87.71%
#
# Epoch 21
#
# Batch   1: Loss = 0.0450 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.1848 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.1564 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.2798 | Accuracy = 75.00%
#
# Batch 2001: Loss = 0.1464 | Accuracy = 100.00%
# ===> Epoch 21 Summary: Total Loss = 620.0982 | Accuracy = 88.25%
#
# Epoch 22
#
# Batch   1: Loss = 0.6917 | Accuracy = 62.50%
#
# Batch 501: Loss = 0.4392 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.5697 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.2757 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.2866 | Accuracy = 87.50%
# ===> Epoch 22 Summary: Total Loss = 598.2490 | Accuracy = 88.56%
#
# Epoch 23
#
# Batch   1: Loss = 0.1918 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.1207 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.8000 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.0208 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.1762 | Accuracy = 87.50%
# ===> Epoch 23 Summary: Total Loss = 565.8305 | Accuracy = 89.27%
#
# Epoch 24
#
# Batch   1: Loss = 0.3688 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.3479 | Accuracy = 75.00%
#
# Batch 1001: Loss = 0.2201 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.5511 | Accuracy = 75.00%
#
# Batch 2001: Loss = 0.1902 | Accuracy = 87.50%
# ===> Epoch 24 Summary: Total Loss = 539.9452 | Accuracy = 89.96%
#
# Epoch 25
#
# Batch   1: Loss = 0.0616 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.1411 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.5430 | Accuracy = 75.00%
#
# Batch 1501: Loss = 0.1418 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.0798 | Accuracy = 100.00%
# ===> Epoch 25 Summary: Total Loss = 516.7342 | Accuracy = 90.51%
#
# Epoch 26
#
# Batch   1: Loss = 0.2161 | Accuracy = 87.50%
#
# Batch 501: Loss = 0.0520 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.2221 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.1655 | Accuracy = 87.50%
#
# Batch 2001: Loss = 0.0915 | Accuracy = 100.00%
# ===> Epoch 26 Summary: Total Loss = 493.3752 | Accuracy = 90.87%
#
# Epoch 27
#
# Batch   1: Loss = 0.0659 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.1028 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.0469 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.0306 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.1031 | Accuracy = 100.00%
# ===> Epoch 27 Summary: Total Loss = 457.6075 | Accuracy = 91.63%
#
# Epoch 28
#
# Batch   1: Loss = 0.1552 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.0951 | Accuracy = 100.00%
#
# Batch 1001: Loss = 0.0977 | Accuracy = 100.00%
#
# Batch 1501: Loss = 0.0987 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.1472 | Accuracy = 100.00%
# ===> Epoch 28 Summary: Total Loss = 428.4981 | Accuracy = 92.01%
#
# Epoch 29
#
# Batch   1: Loss = 0.0073 | Accuracy = 100.00%
#
# Batch 501: Loss = 0.3863 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.6698 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.0727 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.0158 | Accuracy = 100.00%
# ===> Epoch 29 Summary: Total Loss = 420.7400 | Accuracy = 92.33%
#
# Epoch 30
#
# Batch   1: Loss = 0.6458 | Accuracy = 75.00%
#
# Batch 501: Loss = 0.1535 | Accuracy = 87.50%
#
# Batch 1001: Loss = 0.2952 | Accuracy = 87.50%
#
# Batch 1501: Loss = 0.0970 | Accuracy = 100.00%
#
# Batch 2001: Loss = 0.0734 | Accuracy = 100.00%
# ===> Epoch 30 Summary: Total Loss = 389.4824 | Accuracy = 92.96%

# %% [markdown]
# # **Evaluate**

# %%
model.eval()
all_preds, all_labels, all_probs = [], [], []
val_loss = 0.0

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        labels = labels.float().unsqueeze(1)   # (B,1)

        logits = model(images)                 # (B,1)
        loss = criterion(logits, labels)
        val_loss += loss.item()

        probs = torch.sigmoid(logits)          
        preds = (probs > 0.5).long()           

        all_probs.append(probs.cpu().view(-1))     # (B,)
        all_preds.append(preds.cpu().view(-1))     # (B,)
        all_labels.append(labels.cpu().view(-1))   # (B,)

# concatenate
all_probs = torch.cat(all_probs).numpy()
all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

# accuracy
val_acc = accuracy_score(all_labels, all_preds) * 100
print(f"Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_acc:.2f}%")
# Out:
# Validation Loss: 289.7323 | Validation Accuracy: 82.06%

# %%
# ROC + AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
